# %%
import requests
import pandas as pd
from yelpapi import get_my_key
import json

# %%
business_id = "e1zDuraqPYNqfEmgXJJAyQ"

#API_KEY = get_my_key

ENDPORINT = "https://api.yelp.com/v3/businesses/search"

HEADERS = {'Authorization': 'bearer %s' % get_my_key}

# %%
PARAMETERS = {"term": "coffee", "limit": 50, "radius": 5000, "location": "Chicago"}

response = requests.get(url = ENDPORINT, params= PARAMETERS, headers=HEADERS)

business_data = response.json()

business_data
# Out:
# {'businesses': [{'id': 'jImBrAd65LeLWne9lfK2tg',
#    'alias': 'the-wormhole-coffee-chicago',
#    'name': 'The Wormhole Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/C8hsXQdOgvRXqeXVB2_upg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-wormhole-coffee-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 1060,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.90828, 'longitude': -87.67471},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1462 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1462 N Milwaukee Ave', 'Chicago, IL 60622']},
#    'phone': '+17736612468',
#    'display_phone': '(773) 661-2468',
#    'distance': 435.88238733594625},
#   {'id': 'D3v4jl_qKFTDXs5jGrZXIA',
#    'alias': 'coffee-lab-and-roasters-chicago',
#    'name': 'Coffee Lab & Roasters',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/onKT69TQCWi3eKRr5Cgx0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/coffee-lab-and-roasters-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 22,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.93329, 'longitude': -87.65935},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2823 N Lincoln Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2823 N Lincoln Ave', 'Chicago, IL 60657']},
#    'phone': '+17736879453',
#    'display_phone': '(773) 687-9453',
#    'distance': 3480.5754950644723},
#   {'id': 'G-LUoHk_E_XCjSoSsaflFw',
#    'alias': 'sawada-coffee-chicago',
#    'name': 'Sawada Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/byHwU3txl2u1TPs90Jsdqw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sawada-coffee-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 536,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8836669921875,
#     'longitude': -87.6489334106445},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '112 N Green St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['112 N Green St', 'Chicago, IL 60607']},
#    'phone': '+13127540431',
#    'display_phone': '(312) 754-0431',
#    'distance': 3385.8160474523384},
#   {'id': 'CZAVqR6lI50rVbN7E78aHA',
#    'alias': 'ipsento-chicago',
#    'name': 'Ipsento',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/6X1JnKumfOoW61iH8s3UUg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ipsento-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 822,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9186515808105,
#     'longitude': -87.6871032714844},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2035 N Western Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2035 N Western Ave', 'Chicago, IL 60647']},
#    'phone': '+17739048177',
#    'display_phone': '(773) 904-8177',
#    'distance': 1687.467688285902},
#   {'id': 'LzSy-jphOHeHEKDAMJgKfA',
#    'alias': 'dark-matter-coffee-the-mothership-chicago',
#    'name': 'Dark Matter Coffee - The Mothership',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5fLYnGnDJkjYjw6J8tdFxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dark-matter-coffee-the-mothership-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 197,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.89508, 'longitude': -87.68723},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '738 N Western Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60612',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['738 N Western Ave', 'Chicago, IL 60612']},
#    'phone': '+17736978472',
#    'display_phone': '(773) 697-8472',
#    'distance': 1366.683552093674},
#   {'id': 'psDogNivrOWDdQV_TrgtCQ',
#    'alias': 'damn-fine-coffee-bar-chicago-2',
#    'name': 'Damn Fine Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ViIzYxGKutfBu2aFPdkOEQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/damn-fine-coffee-bar-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 71,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9173326747872,
#     'longitude': -87.7108700909343},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3317 W Armitage Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3317 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17739047051',
#    'display_phone': '(773) 904-7051',
#    'distance': 3055.605065531589},
#   {'id': 'f5p7scO1Q9UdaGbYe9bjFg',
#    'alias': 'two-hearted-queen-chicago',
#    'name': 'Two Hearted Queen',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/amS48Qekq3r3tX_sKeKYBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-hearted-queen-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 243,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.9433099, 'longitude': -87.65928},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1201 W Roscoe St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1201 W Roscoe St', 'Chicago, IL 60657']},
#    'phone': '+17733608189',
#    'display_phone': '(773) 360-8189',
#    'distance': 4512.831188922795},
#   {'id': '8IzTjSeBCyAfL7ebLVCWBA',
#    'alias': 'osmium-coffee-bar-chicago',
#    'name': 'Osmium Coffee Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Yt8ZUZ_noFTx_kei9tVEEg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/osmium-coffee-bar-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 239,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9396019, 'longitude': -87.6573029},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1117 W Belmont Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1117 W Belmont Ave', 'Chicago, IL 60657']},
#    'phone': '+17733607553',
#    'display_phone': '(773) 360-7553',
#    'distance': 4197.867588809553},
#   {'id': '5vw7yrtfOQ-2yHa3SZ9c_g',
#    'alias': 'metric-coffee-chicago',
#    'name': 'Metric Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Zt_vcKaotYqNZz4rKVD97g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/metric-coffee-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 42,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8865239, 'longitude': -87.6778928},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2021 W Fulton St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60612',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2021 W Fulton St', 'Chicago, IL 60612']},
#    'phone': '+13129822196',
#    'display_phone': '(312) 982-2196',
#    'distance': 2072.1818095827352},
#   {'id': 'R6vJrf_fooQEOp1H5Q_C_g',
#    'alias': 'sip-coffee-house-and-garden-chicago',
#    'name': 'Sip Coffee House & Garden',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4UVCt-lodnnxBCT-BKhiAQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sip-coffee-house-and-garden-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 404,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8907699584961,
#     'longitude': -87.6583251953125},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1223 W Grand Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60642',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1223 W Grand Ave', 'Chicago, IL 60642']},
#    'phone': '+13125631123',
#    'display_phone': '(312) 563-1123',
#    'distance': 2258.706862727356},
#   {'id': 'BpwVIB258we6x2XwekpFug',
#    'alias': 'cc-ferns-coffee-bar-and-spirits-chicago',
#    'name': 'CC Ferns Coffee Bar & Spirits',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qwINywoHkPaeY4mS1XOKXQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cc-ferns-coffee-bar-and-spirits-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 132,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8994049, 'longitude': -87.6970885},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2806 W Augusta Blvd',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2806 W Augusta Blvd', 'Chicago, IL 60622']},
#    'phone': '+17733842547',
#    'display_phone': '(773) 384-2547',
#    'distance': 1729.6733772151738},
#   {'id': 'vXbg6JOKxfT3PPPYKhgbEw',
#    'alias': 'limitless-coffee-and-tea-fulton-market-chicago',
#    'name': 'Limitless Coffee & Tea - Fulton Market',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ZhamAU2_pIplpjTBAZJMCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/limitless-coffee-and-tea-fulton-market-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 92,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.886248, 'longitude': -87.6485031330763},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '217 N Green St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['217 N Green St', 'Chicago, IL 60607']},
#    'phone': '+13129294643',
#    'display_phone': '(312) 929-4643',
#    'distance': 3207.4679469593293},
#   {'id': 'uGzEhin53O59JzUhkkwCFQ',
#    'alias': 'groundswell-coffee-roasters-chicago-3',
#    'name': 'Groundswell Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ibdGOTiu3ucmelCEtiIRTw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/groundswell-coffee-roasters-chicago-3?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 64,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8817349, 'longitude': -87.6569299},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1168 W Madison St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1168 W Madison St', 'Chicago, IL 60607']},
#    'phone': '+13127632165',
#    'display_phone': '(312) 763-2165',
#    'distance': 3113.2497011332757},
#   {'id': 'cLaMG2ztKxqqLhRRpP9HNg',
#    'alias': 'ipsento-606-chicago',
#    'name': 'Ipsento 606',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5N6MNtpYk8lnJ-HtJFBmTg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/ipsento-606-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 216,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.91443, 'longitude': -87.68326},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1813 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1813 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+18722068697',
#    'display_phone': '(872) 206-8697',
#    'distance': 1126.8480849666093},
#   {'id': 'rYc8maCCT-zleaQdEBKweA',
#    'alias': 'gaslight-coffee-roasters-chicago',
#    'name': 'Gaslight Coffee Roasters',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Cpdxjo05nLdTrTnRLkTixQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gaslight-coffee-roasters-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 266,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.92458, 'longitude': -87.69972},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2385 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2385 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2838.846486843301},
#   {'id': 'Bj-hbYQLeoJd422inI6E2A',
#    'alias': 'star-lounge-coffee-bar-chicago',
#    'name': 'Star Lounge Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/P_-o3iTAIo3VO5_9w-S1kg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/star-lounge-coffee-bar-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 516,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.89544, 'longitude': -87.69017},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2521 W Chicago Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2521 W Chicago Ave', 'Chicago, IL 60622']},
#    'phone': '+17733847827',
#    'display_phone': '(773) 384-7827',
#    'distance': 1485.5016891028706},
#   {'id': 'TDlyJXTZRkQCiVJWAZGIiQ',
#    'alias': 'printers-row-coffee-chicago-5',
#    'name': "Printer's Row Coffee",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9mhNHsyP0YFlXGtj91uODA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/printers-row-coffee-chicago-5?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 37,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.9269405337141,
#     'longitude': -87.650963571668},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2482 N Lincoln Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2482 N Lincoln Ave', 'Chicago, IL 60614']},
#    'phone': '+17736665394',
#    'display_phone': '(773) 666-5394',
#    'distance': 3276.1776973521264},
#   {'id': '_xEt9Mn4HfkExbwE3_BmoQ',
#    'alias': 'the-avondale-coffee-club-chicago',
#    'name': 'The Avondale Coffee Club',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/XL1vdPZCNaYAw9JHN94kAg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-avondale-coffee-club-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.9391799714153,
#     'longitude': -87.6978301629424},
#    'transactions': [],
#    'location': {'address1': '3185 N Elston Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60618',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3185 N Elston Ave', 'Chicago, IL 60618']},
#    'phone': '+17737548140',
#    'display_phone': '(773) 754-8140',
#    'distance': 4131.156739707344},
#   {'id': 'qYTLqAtRvJ-RczO40sAFvg',
#    'alias': 'sip-of-hope-chicago-2',
#    'name': 'Sip of Hope',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1ywR_qbZTRGRLHj8vz_LOQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sip-of-hope-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.92444, 'longitude': -87.70389},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3039 W Fullerton Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3039 W Fullerton Ave', 'Chicago, IL 60647']},
#    'phone': '+17736616986',
#    'display_phone': '(773) 661-6986',
#    'distance': 3044.9318607084356},
#   {'id': 'RPM72yznTH3x6rQGR4AGGQ',
#    'alias': 'purple-llama-chicago-3',
#    'name': 'Purple Llama',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FzMgGVjPqU9lDZhr6HNLCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/purple-llama-chicago-3?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 50,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'vinyl_records', 'title': 'Vinyl Records'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.90338, 'longitude': -87.68131},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2140 W Division St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2140 W Division St', 'Chicago, IL 60622']},
#    'phone': '+17736879900',
#    'display_phone': '(773) 687-9900',
#    'distance': 360.17979811989926},
#   {'id': 'RJ15GOIUTEAfmmZufGGscw',
#    'alias': 'standing-passengers-chicago',
#    'name': 'Standing Passengers',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/nPBXXIzIhjlBll8vfQoEiw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/standing-passengers-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 58,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'galleries', 'title': 'Art Galleries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.89638, 'longitude': -87.66468},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1458 W Chicago Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60642',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1458 W Chicago Ave', 'Chicago, IL 60642']},
#    'phone': '+13123743177',
#    'display_phone': '(312) 374-3177',
#    'distance': 1460.755035924354},
#   {'id': 'xlNLjn6cK_Bz1tgchAiYXA',
#    'alias': 'dark-matter-coffee-electric-mud-coffee-bar-chicago',
#    'name': 'Dark Matter Coffee - Electric Mud Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YNEwK2URU99ygEu37q51AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dark-matter-coffee-electric-mud-coffee-bar-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 18,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.9155702, 'longitude': -87.6877},
#    'transactions': [],
#    'location': {'address1': '1856 N Western Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1856 N Western Ave', 'Chicago, IL 60647']},
#    'phone': '+17736986086',
#    'display_phone': '(773) 698-6086',
#    'distance': 1419.8722595545564},
#   {'id': '4hhsyYChjYkXWxEfhyvcfw',
#    'alias': 'la-colombe-coffee-chicago-3',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kBTTRocMxiy0EFf7tZsV8Q/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-chicago-3?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 431,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.884110942717, 'longitude': -87.651928959323},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '955 W Randolph St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['955 W Randolph St', 'Chicago, IL 60607']},
#    'phone': '+13127330707',
#    'display_phone': '(312) 733-0707',
#    'distance': 3170.2921183269655},
#   {'id': 'yztPuQzo3BGH-Xq-9iDDnA',
#    'alias': 'loba-pastry-coffee-chicago',
#    'name': 'Loba Pastry + Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fFz-zW6odhCM3rPbWp8ERA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/loba-pastry-coffee-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 63,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.94389, 'longitude': -87.672},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3422 N Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3422 N Lincoln Ave', 'Chicago, IL 60657']},
#    'phone': '+17734569266',
#    'display_phone': '(773) 456-9266',
#    'distance': 4341.360002975508},
#   {'id': 'JBjTfJBv1n40MXD_lNImbQ',
#    'alias': 'elaines-coffee-call-chicago',
#    'name': "Elaine's Coffee Call",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/oQqIf42u9GI5_UsV2jyFgg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elaines-coffee-call-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 125,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9153347, 'longitude': -87.6345497},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1816 N Clark St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1816 N Clark St', 'Chicago, IL 60614']},
#    'phone': '+13122544665',
#    'display_phone': '(312) 254-4665',
#    'distance': 3750.7958065432776},
#   {'id': 'MpVZfqGxXs-wWk91VtxKFQ',
#    'alias': 'colectivo-coffee-chicago-2',
#    'name': 'Colectivo Coffee',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rst0Ku1zGgSxgR0y4g2MHw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/colectivo-coffee-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 68,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9222326, 'longitude': -87.6960043},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '2261 N Milwaukee Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2261 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17737998557',
#    'display_phone': '(773) 799-8557',
#    'distance': 2416.3680757836682},
#   {'id': '12qhu01BPopgTDEFh1S6xg',
#    'alias': 'pan-artesanal-chicago',
#    'name': 'Pan Artesanal',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/pBEn6mELtVL29Pw_Ni4eZQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pan-artesanal-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 66,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9247354245118,
#     'longitude': -87.7204674619309},
#    'transactions': ['delivery', 'pickup'],
#    'location': {'address1': '3724 W Fullerton Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3724 W Fullerton Ave', 'Chicago, IL 60647']},
#    'phone': '+13122865265',
#    'display_phone': '(312) 286-5265',
#    'distance': 4150.079954446246},
#   {'id': 'tU35AE1xllpE7ecXrYIqxQ',
#    'alias': 'intelligentsia-coffee-chicago-7',
#    'name': 'Intelligentsia Coffee',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6OKnZ8iEYGuCcbVfnjmLyw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/intelligentsia-coffee-chicago-7?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 123,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9049884729, 'longitude': -87.6343021156},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1233 N Wells',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60610',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1233 N Wells', 'Chicago, IL 60610']},
#    'phone': '+13122291400',
#    'display_phone': '(312) 229-1400',
#    'distance': 3596.8991078922068},
#   {'id': 'lIExarJifku_yqQPIuP4Tg',
#    'alias': 'the-coffee-alley-chicago',
#    'name': 'The Coffee Alley',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/rPNnAG0tnnw7A6lB532pcA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-coffee-alley-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 174,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.8694985998054,
#     'longitude': -87.6563778303571},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1152 W Taylor',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1152 W Taylor', 'Chicago, IL 60607']},
#    'phone': '+13123744976',
#    'display_phone': '(312) 374-4976',
#    'distance': 4342.560628715726},
#   {'id': 'UlVhN2UMRAUjvHuNc4blug',
#    'alias': 'hope-cafe-chicago',
#    'name': 'Hope Cafe',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/pwZdc17t9aoK6yS714zl3A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/hope-cafe-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 62,
#    'categories': [{'alias': 'venues', 'title': 'Venues & Event Spaces'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.866387, 'longitude': -87.68732},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '2431 W Roosevelt Rd',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60608',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2431 W Roosevelt Rd', 'Chicago, IL 60608']},
#    'phone': '+13128576499',
#    'display_phone': '(312) 857-6499',
#    'distance': 4383.234541817491},
#   {'id': 'X-z5JOtqDDdMsQsN-06mtA',
#    'alias': 'la-colombe-coffee-chicago-2',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/O067zScL8LdcxijvbvjNng/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 143,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9097887, 'longitude': -87.6776413},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1552 N Damen Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1552 N Damen Ave', 'Chicago, IL 60622']},
#    'phone': '+18728293681',
#    'display_phone': '(872) 829-3681',
#    'distance': 514.2365937307999},
#   {'id': 'tQUclCl0fi99Od2vN0jsUg',
#    'alias': 'caffe-umbria-chicago-7',
#    'name': 'Caffe Umbria',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VopjEPYWFdf2nxaNMpcfmA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/caffe-umbria-chicago-7?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 37,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9174151, 'longitude': -87.6916053},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2545 W Armitage Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2545 W Armitage Ave', 'Chicago, IL 60647']},
#    'phone': '+17733608643',
#    'display_phone': '(773) 360-8643',
#    'distance': 1770.2456057506652},
#   {'id': 'gxUFFsSLa-IyouuRD2Ma6w',
#    'alias': 'spinning-j-chicago-2',
#    'name': 'Spinning J',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bJBzdl7-U4tLEP-yOr5K5w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/spinning-j-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 315,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.899391, 'longitude': -87.696991},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1000 N California Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60622',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1000 N California Ave', 'Chicago, IL 60622']},
#    'phone': '+18728292793',
#    'display_phone': '(872) 829-2793',
#    'distance': 1715.5754765570414},
#   {'id': 'ra4hdxs2teadi4GMpGMTIw',
#    'alias': 'meddle-coffee-bar-chicago-3',
#    'name': 'Meddle Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/p7vY48UbDdBUuUCXokyJ5g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/meddle-coffee-bar-chicago-3?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 78,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8779047891568,
#     'longitude': -87.6427854757224},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '601 West Jackson Blvd',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60661',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['601 West Jackson Blvd', 'Chicago, IL 60661']},
#    'phone': '+13126313553',
#    'display_phone': '(312) 631-3553',
#    'distance': 4191.376450685668},
#   {'id': 'inm4szLHpZ-mt01LRR4nhw',
#    'alias': 'four-letter-word-chicago',
#    'name': 'Four Letter Word',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RNEiDSndDNLcqkZw_3NKDA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/four-letter-word-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 9,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.9323, 'longitude': -87.70348},
#    'transactions': [],
#    'location': {'address1': '3022 W Diversey Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3022 W Diversey Ave', 'Chicago, IL 60647']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 3691.112032927312},
#   {'id': 'P-klV9Y33QAaQ9I6z0UaQQ',
#    'alias': 'l-ours-bakery-cafe-chicago',
#    'name': "L'Ours Bakery Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tclD5S7Cqfbc-aMpF5-wlw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-ours-bakery-cafe-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 31,
#    'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#     {'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.86957, 'longitude': -87.66266},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1424 W Taylor St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1424 W Taylor St', 'Chicago, IL 60607']},
#    'phone': '+13122650958',
#    'display_phone': '(312) 265-0958',
#    'distance': 4154.902163241359},
#   {'id': 'bwuvq9JIhlo8E40kDCgImA',
#    'alias': 'werewolf-coffee-bar-chicago-2',
#    'name': 'Werewolf Coffee Bar',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/3y_E4Q2gQyMcu87l1k0Fsg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/werewolf-coffee-bar-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 89,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 41.9145977740557,
#     'longitude': -87.6642566666733},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1765 N Elston Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60642',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1765 N Elston Ave', 'Chicago, IL 60642']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 1533.2947471253149},
#   {'id': 'rnMkUiazBHiFoGD82emRPQ',
#    'alias': 'stumptown-coffee-roasters-chicago',
#    'name': 'Stumptown Coffee Roasters',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/uK_VAo7cTqLAC1IJtctoJQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/stumptown-coffee-roasters-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 41,
#    'categories': [{'alias': 'coffeeroasteries', 'title': 'Coffee Roasteries'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.88717, 'longitude': -87.65184},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '311 N Morgan St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['311 N Morgan St', 'Chicago, IL 60607']},
#    'phone': '+18557113385',
#    'display_phone': '(855) 711-3385',
#    'distance': 2933.5230544134397},
#   {'id': 's1j47h7o3K0m9U7P1f_AAw',
#    'alias': 'dropshot-coffee-and-snack-bar-chicago-2',
#    'name': 'DropShot Coffee & Snack Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ch2pRx3odOxAKGJhsiV6Hg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dropshot-coffee-and-snack-bar-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 57,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.89857, 'longitude': -87.63641},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '312 W Chestnut St',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60610',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['312 W Chestnut St', 'Chicago, IL 60610']},
#    'phone': '+13124963014',
#    'display_phone': '(312) 496-3014',
#    'distance': 3500.3904424352995},
#   {'id': 'IYAeo0sLwQfGJ0WXuL8jQg',
#    'alias': 'la-strada-cafe-bar-chicago',
#    'name': 'La Strada Cafe Bar',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/RN8MIe7sXJB6VkuUpT-8Tw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-strada-cafe-bar-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 114,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.91837, 'longitude': -87.69695},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2023 N California Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2023 N California Ave', 'Chicago, IL 60647']},
#    'phone': '+17086270403',
#    'display_phone': '(708) 627-0403',
#    'distance': 2161.2232777120726},
#   {'id': 'n2QDUYydYa1KMyuGPeDMjw',
#    'alias': 'cafe-mustache-chicago',
#    'name': 'Cafe Mustache',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/zpzfrq1mbEztb9RmTcDbbg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-mustache-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 245,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9232653, 'longitude': -87.6976673},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '2313 N Milwaukee Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2313 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17736879063',
#    'display_phone': '(773) 687-9063',
#    'distance': 2613.79983143347},
#   {'id': 'OPjXdkm5y_ARr6oyeEOMfg',
#    'alias': 'fairgrounds-coffee-and-tea-chicago',
#    'name': 'Fairgrounds Coffee and Tea',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/439M84S8LQAQppQJ5lIGkA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/fairgrounds-coffee-and-tea-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 214,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9106987115516,
#     'longitude': -87.6780348762432},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1620 N Milwaukee Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60647',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1620 N Milwaukee Ave', 'Chicago, IL 60647']},
#    'phone': '+17737703444',
#    'display_phone': '(773) 770-3444',
#    'distance': 623.2109240725156},
#   {'id': 'kLY282iFmjFw1U6M2BWPYQ',
#    'alias': 'cocoa-co-chicago',
#    'name': 'Cocoa + Co.',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/cT6uPpWK5bZgbydscHtzyA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cocoa-co-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 108,
#    'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bakeries', 'title': 'Bakeries'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9126, 'longitude': -87.63431},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1651 N Wells St',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1651 N Wells St', 'Chicago, IL 60614']},
#    'phone': '+13126248540',
#    'display_phone': '(312) 624-8540',
#    'distance': 3673.998138015182},
#   {'id': 'ZMmdSK4oObGNCv50tT1OOA',
#    'alias': 'evas-cafe-chicago-2',
#    'name': "Eva's Cafe",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/CcbNccSOvkU5vgmGQAv00w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/evas-cafe-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 230,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9089825, 'longitude': -87.6384134},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$',
#    'location': {'address1': '1447 N Sedgwick',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60610',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['1447 N Sedgwick', 'Chicago, IL 60610']},
#    'phone': '+13122808900',
#    'display_phone': '(312) 280-8900',
#    'distance': 3284.1415380431395},
#   {'id': 'KCdjOex0XuSHgHBBhWEW9Q',
#    'alias': 'la-colombe-coffee-chicago-4',
#    'name': 'La Colombe Coffee',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FseJJoCH6hltYeAmX6Thtw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-colombe-coffee-chicago-4?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 60,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9182445724707,
#     'longitude': -87.6508014417597},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '858 W Armitage Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['858 W Armitage Ave', 'Chicago, IL 60614']},
#    'phone': '+17735729685',
#    'display_phone': '(773) 572-9685',
#    'distance': 2663.6922806916564},
#   {'id': 'vYwl7HjiIi-BwvLhRc6sjg',
#    'alias': 'heritage-bikes-and-coffee-chicago-2',
#    'name': 'Heritage Bikes and Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q0CHMPgghPhDtGme3W9Otw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heritage-bikes-and-coffee-chicago-2?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 5,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bikes', 'title': 'Bikes'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.8848865, 'longitude': -87.6569349},
#    'transactions': [],
#    'location': {'address1': '172 N Racine',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60607',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['172 N Racine', 'Chicago, IL 60607']},
#    'phone': '+17732453005',
#    'display_phone': '(773) 245-3005',
#    'distance': 2817.2357606209403},
#   {'id': 'sUWKv886Sv24sc8IZugUkQ',
#    'alias': 'elevate-coffee-chicago',
#    'name': 'Elevate Coffee',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/5NTqnbt16UWZHfK0WGphRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/elevate-coffee-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 8,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 41.94314, 'longitude': -87.64972},
#    'transactions': [],
#    'location': {'address1': '3344 N Halsted St',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3344 N Halsted St', 'Chicago, IL 60657']},
#    'phone': '+17738573002',
#    'display_phone': '(773) 857-3002',
#    'distance': 4822.407787509517},
#   {'id': 'xMtXy7YAslpvjqaYT3KEIw',
#    'alias': 'heritage-bicycles-general-store-chicago',
#    'name': 'Heritage Bicycles General Store',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/I4Ip7MHXTomCg49aVRd2AQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/heritage-bicycles-general-store-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 278,
#    'categories': [{'alias': 'bikes', 'title': 'Bikes'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'bike_repair_maintenance', 'title': 'Bike Repair/Maintenance'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.9356745, 'longitude': -87.6629425},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '2959 N Lincoln Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60657',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['2959 N Lincoln Ave', 'Chicago, IL 60657']},
#    'phone': '+17732453005',
#    'display_phone': '(773) 245-3005',
#    'distance': 3607.954954019368},
#   {'id': 'ffDtkXhHwMxx2R7_AqVZpA',
#    'alias': 'department-of-coffee-and-social-affairs-chicago',
#    'name': 'Department of Coffee and Social Affairs',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WZnpOJF6yHuMK_9XVrLhTA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/department-of-coffee-and-social-affairs-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 44,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 41.9328314, 'longitude': -87.6492367},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '800 W Diversey',
#     'address2': '',
#     'address3': None,
#     'city': 'Chicago',
#     'zip_code': '60614',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['800 W Diversey', 'Chicago, IL 60614']},
#    'phone': '+17736979581',
#    'display_phone': '(773) 697-9581',
#    'distance': 3878.2295493029796},
#   {'id': 'fcEL1Z3zGARv4upUvSWjiw',
#    'alias': 'bridge-cafe-chicago',
#    'name': 'Bridge Cafe',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1kDNwKMc4s6t60r99mWciA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bridge-cafe-chicago?adjust_creative=e1zDuraqPYNqfEmgXJJAyQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=e1zDuraqPYNqfEmgXJJAyQ',
#    'review_count': 7,
#    'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 41.8873702, 'longitude': -87.7074775},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '3219 W Carroll Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Chicago',
#     'zip_code': '60624',
#     'country': 'US',
#     'state': 'IL',
#     'display_address': ['3219 W Carroll Ave', 'Chicago, IL 60624']},
#    'phone': '+18724448200',
#    'display_phone': '(872) 444-8200',
#    'distance': 3152.5593861844486}],
#  'total': 944,
#  'region': {'center': {'longitude': -87.67776489257812,
#    'latitude': 41.90515925618311}}}

# %%
good_coffee = business_data["businesses"]
good_coffee_df = pd.DataFrame(good_coffee)
good_coffee_df = good_coffee_df[["name","is_closed","categories","review_count","rating","location"]]
good_coffee_df
# Out:
#                                             name  is_closed  \
# 0                            The Wormhole Coffee      False
# 1                          Coffee Lab & Roasters      False
# 2                                  Sawada Coffee      False
# 3                                        Ipsento      False
# 4            Dark Matter Coffee - The Mothership      False
# 5                           Damn Fine Coffee Bar      False
# 6                              Two Hearted Queen      False
# 7                              Osmium Coffee Bar      False
# 8                                  Metric Coffee      False
# 9                      Sip Coffee House & Garden      False
# 10                 CC Ferns Coffee Bar & Spirits      False
# 11        Limitless Coffee & Tea - Fulton Market      False
# 12                   Groundswell Coffee Roasters      False
# 13                                   Ipsento 606      False
# 14                      Gaslight Coffee Roasters      False
# 15                        Star Lounge Coffee Bar      False
# 16                          Printer's Row Coffee      False
# 17                      The Avondale Coffee Club      False
# 18                                   Sip of Hope      False
# 19                                  Purple Llama      False
# 20                           Standing Passengers      False
# 21  Dark Matter Coffee - Electric Mud Coffee Bar      False
# 22                             La Colombe Coffee      False
# 23                          Loba Pastry + Coffee      False
# 24                          Elaine's Coffee Call      False
# 25                              Colectivo Coffee      False
# 26                                 Pan Artesanal      False
# 27                         Intelligentsia Coffee      False
# 28                              The Coffee Alley      False
# 29                                     Hope Cafe      False
# 30                             La Colombe Coffee      False
# 31                                  Caffe Umbria      False
# 32                                    Spinning J      False
# 33                             Meddle Coffee Bar      False
# 34                              Four Letter Word      False
# 35                            L'Ours Bakery Cafe      False
# 36                           Werewolf Coffee Bar      False
# 37                     Stumptown Coffee Roasters      False
# 38                   DropShot Coffee & Snack Bar      False
# 39                            La Strada Cafe Bar      False
# 40                                 Cafe Mustache      False
# 41                    Fairgrounds Coffee and Tea      False
# 42                                   Cocoa + Co.      False
# 43                                    Eva's Cafe      False
# 44                             La Colombe Coffee      False
# 45                     Heritage Bikes and Coffee      False
# 46                                Elevate Coffee      False
# 47               Heritage Bicycles General Store      False
# 48       Department of Coffee and Social Affairs      False
# 49                                   Bridge Cafe      False
#
#                                            categories  review_count  rating  \
# 0   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...          1060     4.5
# 1   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            22     5.0
# 2      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           536     4.5
# 3   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           822     4.5
# 4      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           197     4.5
# 5   [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            71     4.5
# 6      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           243     5.0
# 7      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           239     4.5
# 8   [{'alias': 'coffeeroasteries', 'title': 'Coffe...            42     4.5
# 9      [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           404     4.5
# 10  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           132     4.5
# 11  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            92     4.0
# 12  [{'alias': 'coffeeroasteries', 'title': 'Coffe...            64     4.5
# 13  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           216     4.5
# 14  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...           266     4.0
# 15     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           516     4.5
# 16  [{'alias': 'coffeeroasteries', 'title': 'Coffe...            37     5.0
# 17     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]            37     5.0
# 18     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]            63     5.0
# 19  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            50     4.5
# 20  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            58     4.5
# 21  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...            18     5.0
# 22     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           431     4.0
# 23  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            63     4.5
# 24             [{'alias': 'cafes', 'title': 'Cafes'}]           125     4.0
# 25  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            68     4.5
# 26  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            66     4.5
# 27     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           123     4.0
# 28  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           174     4.0
# 29  [{'alias': 'venues', 'title': 'Venues & Event ...            62     4.5
# 30     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           143     4.0
# 31  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            37     4.0
# 32  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           315     4.5
# 33     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]            78     4.5
# 34     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]             9     5.0
# 35  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...            31     4.5
# 36     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]            89     3.5
# 37  [{'alias': 'coffeeroasteries', 'title': 'Coffe...            41     4.0
# 38  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...            57     4.5
# 39  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           114     4.5
# 40     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]           245     4.0
# 41  [{'alias': 'breakfast_brunch', 'title': 'Break...           214     4.5
# 42  [{'alias': 'desserts', 'title': 'Desserts'}, {...           108     4.5
# 43  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...           230     4.5
# 44     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]            60     4.0
# 45  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...             5     5.0
# 46     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]             8     5.0
# 47  [{'alias': 'bikes', 'title': 'Bikes'}, {'alias...           278     4.5
# 48     [{'alias': 'coffee', 'title': 'Coffee & Tea'}]            44     4.0
# 49  [{'alias': 'coffee', 'title': 'Coffee & Tea'},...             7     4.5
#
#                                              location
# 0   {'address1': '1462 N Milwaukee Ave', 'address2...
# 1   {'address1': '2823 N Lincoln Ave', 'address2':...
# 2   {'address1': '112 N Green St', 'address2': Non...
# 3   {'address1': '2035 N Western Ave', 'address2':...
# 4   {'address1': '738 N Western Ave', 'address2': ...
# 5   {'address1': '3317 W Armitage Ave', 'address2'...
# 6   {'address1': '1201 W Roscoe St', 'address2': '...
# 7   {'address1': '1117 W Belmont Ave', 'address2':...
# 8   {'address1': '2021 W Fulton St', 'address2': '...
# 9   {'address1': '1223 W Grand Ave', 'address2': '...
# 10  {'address1': '2806 W Augusta Blvd', 'address2'...
# 11  {'address1': '217 N Green St', 'address2': '',...
# 12  {'address1': '1168 W Madison St', 'address2': ...
# 13  {'address1': '1813 N Milwaukee Ave', 'address2...
# 14  {'address1': '2385 N Milwaukee Ave', 'address2...
# 15  {'address1': '2521 W Chicago Ave', 'address2':...
# 16  {'address1': '2482 N Lincoln Ave', 'address2':...
# 17  {'address1': '3185 N Elston Ave', 'address2': ...
# 18  {'address1': '3039 W Fullerton Ave', 'address2...
# 19  {'address1': '2140 W Division St', 'address2':...
# 20  {'address1': '1458 W Chicago Ave', 'address2':...
# 21  {'address1': '1856 N Western Ave', 'address2':...
# 22  {'address1': '955 W Randolph St', 'address2': ...
# 23  {'address1': '3422 N Lincoln Ave', 'address2':...
# 24  {'address1': '1816 N Clark St', 'address2': ''...
# 25  {'address1': '2261 N Milwaukee Ave', 'address2...
# 26  {'address1': '3724 W Fullerton Ave', 'address2...
# 27  {'address1': '1233 N Wells', 'address2': '', '...
# 28  {'address1': '1152 W Taylor', 'address2': '', ...
# 29  {'address1': '2431 W Roosevelt Rd', 'address2'...
# 30  {'address1': '1552 N Damen Ave', 'address2': '...
# 31  {'address1': '2545 W Armitage Ave', 'address2'...
# 32  {'address1': '1000 N California Ave', 'address...
# 33  {'address1': '601 West Jackson Blvd', 'address...
# 34  {'address1': '3022 W Diversey Ave', 'address2'...
# 35  {'address1': '1424 W Taylor St', 'address2': '...
# 36  {'address1': '1765 N Elston Ave', 'address2': ...
# 37  {'address1': '311 N Morgan St', 'address2': ''...
# 38  {'address1': '312 W Chestnut St', 'address2': ...
# 39  {'address1': '2023 N California Ave', 'address...
# 40  {'address1': '2313 N Milwaukee Ave', 'address2...
# 41  {'address1': '1620 N Milwaukee Ave', 'address2...
# 42  {'address1': '1651 N Wells St', 'address2': ''...
# 43  {'address1': '1447 N Sedgwick', 'address2': No...
# 44  {'address1': '858 W Armitage Ave', 'address2':...
# 45  {'address1': '172 N Racine', 'address2': None,...
# 46  {'address1': '3344 N Halsted St', 'address2': ...
# 47  {'address1': '2959 N Lincoln Ave', 'address2':...
# 48  {'address1': '800 W Diversey', 'address2': '',...
# 49  {'address1': '3219 W Carroll Ave', 'address2':...

# %%
good_coffee_df
